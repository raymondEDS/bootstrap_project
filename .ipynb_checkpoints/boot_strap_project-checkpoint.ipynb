# %%
import itertools
import sklearn
import pandas as pd
import json
import numpy as np
import ast
from tqdm.auto import tqdm
import statistics
import math
import csv
from sklearn.neighbors import NearestNeighbors
from sklearn.neighbors import NearestCentroid
from sklearn.cluster import AgglomerativeClustering
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, StratifiedKFold, StratifiedShuffleSplit
from sklearn.calibration import calibration_curve
from sklearn.manifold import TSNE
from copy import deepcopy
import pprint
import ast
import statistics
import math
import time
from sklearn.metrics import (
    f1_score,
    accuracy_score,
    mean_squared_error,
    r2_score,
    roc_auc_score,
    average_precision_score,
)
import matplotlib.pyplot as plt
from nltk import agreement
import scipy.stats as stats
import seaborn as sns
np.random.seed(1)

tqdm.pandas()

# %% [markdown]
# # Lambda Functions

# %%
embedding_path = 'df_embeddings.csv'
submission_path = 'df_submission_rating.csv'


df_embeddings = pd.read_csv(embedding_path)
df_embeddings = df_embeddings.T
df_embeddings.columns=df_embeddings.iloc[0]
df_embeddings = df_embeddings.iloc[1: , :]


tqdm.pandas()
def get_numpy (row):
  return ast.literal_eval(row.embedding)

df_embeddings['embedding'] = df_embeddings.apply(lambda x: get_numpy(x), axis =1)

df_submissions = pd.read_csv(submission_path)
df_submission_labels = df_submissions[['id','title','conf_year','keywords','AVG_rating']]

df_embeddings_2017 = df_embeddings.merge(df_submission_labels[df_submission_labels['conf_year']==2017], left_on='paper_id',right_on='id')
df_embeddings_2018 = df_embeddings.merge(df_submission_labels[df_submission_labels['conf_year']==2018], left_on='paper_id',right_on='id')
assert df_submission_labels[df_submission_labels['conf_year']==2017].shape[0] == df_embeddings_2017.shape[0]

# %%
def lambda_get_2018_matches(row, dict_agg_cluster_matches):
    #get embedding matches from 2018 papers
    #returning relevant information
    df_clustered_papers = dict_agg_cluster_matches[row.agg_cluster]
    
    lst_paper_titles = df_clustered_papers[0].title.tolist()
    lst_paper_ids = df_clustered_papers[0].paper_id.tolist()
    ls_paper_keywords = df_clustered_papers[0].keywords.values.tolist()
    ls_cos_distances = df_clustered_papers[1]
    
    return lst_paper_titles, ls_paper_keywords, lst_paper_ids, ls_cos_distances
def get_num_knn_matches(row):
    count = len(row.titles_2018)
    return(len(row.titles_2018))

def lambda_get_match_potential_outcomes(row):
    #equation 7 in the paper
    paper_ids = row.id_2018
    big_m = len(row.id_2018)
    if big_m == 0:
        return None
    ratings = [df_embeddings_2018[df_embeddings_2018['paper_id'] == paper_id].AVG_rating.values[0] for paper_id in paper_ids]
    return sum(ratings)/big_m

# %%
def KNN_matching(df_control,df_treat):
    
    tuning_param_knn = 10
    tuning_param_cos_dist = 0.234535



    x = np.array(df_control.embedding.tolist())
    clustering = AgglomerativeClustering(n_clusters=None, distance_threshold=0.1, linkage="average", metric = 'cosine').fit(x)

    df_control['agg_cluster'] = clustering.labels_.tolist()


    neigh = NearestNeighbors( n_neighbors=tuning_param_knn, metric = 'cosine', radius = 0.3)
    non_anchor_embedding_2018 = np.array(df_treat.embedding.to_list())
    neigh.fit(non_anchor_embedding_2018)

    #setting up closest centroid for anchor group 2017
    anchor_embedding_2017 = np.array(df_control.embedding.tolist())
    anchor_agg_clusters_2017 = np.array(df_control.agg_cluster.tolist())
    clf = NearestCentroid()
    clf.fit(anchor_embedding_2017, anchor_agg_clusters_2017)


    #dictionary of all the agg clusters and the 20 KNN from 2018
    dict_agg_cluster_matches ={}
    for cluster_id in np.unique(clustering.labels_):

        distances, indices = neigh.kneighbors([clf.centroids_[cluster_id]])
        df_anchor_embedding = pd.concat([pd.DataFrame(data = distances.T,columns =['cos_dist']),pd.DataFrame(indices.T,columns=['indices'])],axis=1)

        #get all the specified cosine distance 2018 papers
        #tuple of (dataframe of 2018 matched papers, cosine distances)
        dict_agg_cluster_matches[cluster_id] = (
            df_treat.iloc[df_anchor_embedding[df_anchor_embedding['cos_dist']<= tuning_param_cos_dist].indices.to_list(), :],
            df_anchor_embedding[df_anchor_embedding['cos_dist']<= tuning_param_cos_dist].cos_dist.to_list()
        )



    df_control[['titles_2018','keywords_2018','id_2018','cos_dist_2018']]= df_control.apply(lambda x: lambda_get_2018_matches(x, dict_agg_cluster_matches),axis=1, result_type ='expand')


    df_control['num_knn_matches'] = df_control.apply(lambda x: get_num_knn_matches(x),axis =1)


    #Matching potential outcome estimator
    #Keith et al. 2020
    #https://aclanthology.org/2020.acl-main.474.pdf
    #equation 7 and 8
    df_control['match_ave_rating'] = df_control.apply(lambda row: lambda_get_match_potential_outcomes(row), axis =1)
    df_control['diff_2018_2017'] = df_control['match_ave_rating'] - df_control['AVG_rating']

    df_control = df_control.loc[df_control['match_ave_rating'].notnull(),]

    #equation 8 in the paper
    ATT = (df_control['match_ave_rating'] - df_control['AVG_rating']).sum()/df_control.shape[0]

    STD = ((df_control['match_ave_rating'] - df_control['AVG_rating'])).std()
    
    return ATT, STD

# %% [markdown]
# # Standard bootstrap estimator - Wrong according to https://www.jstor.org/stable/40056514

# %%
S = 100
B = 100

boot_SE = []
for i in tqdm(range(S)):
    
    B_ATT = []
    B_STD = []
    for i in range(B):
        boot_2017 = df_embeddings_2017.sample(n=df_embeddings_2017.shape[0], replace=True)
        boot_2018 = df_embeddings_2018.sample(n=df_embeddings_2018.shape[0], replace=True)

        ATT, STD = KNN_matching(boot_2017,boot_2018)
        B_ATT.append(ATT)
        B_STD.append(STD)
    
    mean_B_ATT = np.mean(B_ATT)

    holder_list = []
    for b in B_ATT:
        holder_list.append((b-mean_B_ATT)**2)

    SE = np.sqrt((1/(len(B_ATT)-1)) * sum(holder_list))
    
    boot_SE.append(SE)
    
    
plt.hist(boot_SE)

pd.DataFrame(boot_SE).to_csv('sample_se_failed')
# Out:
#  16%|██████▏                                | 16/100 [40:01<3:30:09, 150.12s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[51], line 13
#      10 boot_2017 = df_embeddings_2017.sample(n=df_embeddings_2017.shape[0], replace=True)
#      11 boot_2018 = df_embeddings_2018.sample(n=df_embeddings_2018.shape[0], replace=True)
# ---> 13 ATT, STD = KNN_matching(boot_2017,boot_2018)
#      14 B_ATT.append(ATT)
#      15 B_STD.append(STD)
#
# Cell In[20], line 30, in KNN_matching(df_control, df_treat)
#      27 for cluster_id in np.unique(clustering.labels_):
#      29     distances, indices = neigh.kneighbors([clf.centroids_[cluster_id]])
# ---> 30     df_anchor_embedding = pd.concat([pd.DataFrame(data = distances.T,columns =['cos_dist']),pd.DataFrame(indices.T,columns=['indices'])],axis=1)
#      32     #get all the specified cosine distance 2018 papers
#      33     #tuple of (dataframe of 2018 matched papers, cosine distances)
#      34     dict_agg_cluster_matches[cluster_id] = (
#      35         df_treat.iloc[df_anchor_embedding[df_anchor_embedding['cos_dist']<= tuning_param_cos_dist].indices.to_list(), :],
#      36         df_anchor_embedding[df_anchor_embedding['cos_dist']<= tuning_param_cos_dist].cos_dist.to_list()
#      37     )
#
# File /opt/anaconda3/envs/nlp/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/nlp/lib/python3.10/site-packages/pandas/core/reshape/concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     146 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     147 def concat(
#     148     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     157     copy: bool = True,
#     158 ) -> DataFrame | Series:
#     159     """
#     160     Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#     371         ignore_index=ignore_index,
#     372         join=join,
#     373         keys=keys,
#     374         levels=levels,
#     375         names=names,
#     376         verify_integrity=verify_integrity,
#     377         copy=copy,
#     378         sort=sort,
#     379     )
#     381     return op.get_result()
#
# File /opt/anaconda3/envs/nlp/lib/python3.10/site-packages/pandas/core/reshape/concat.py:563, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     560 self.verify_integrity = verify_integrity
#     561 self.copy = copy
# --> 563 self.new_axes = self._get_new_axes()
#
# KeyboardInterrupt:

# %%
plt.hist(boot_SE)

pd.DataFrame(boot_SE).to_csv('sample_se_failed')

# %%
x = np.array(df_embeddings_2017.embedding.to_list())

df_embeddings_2017[['TSNE']] = TSNE(n_components=1, learning_rate='auto',init='random').fit_transform(x)

# %%
tuning_param_knn = 10
tuning_param_cos_dist = 0.234535


#5 strata https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5949912/
#get the blocks
x = np.array(df_embeddings_2017.embedding.to_list())
df_embeddings_2017[['TSNE']] = TSNE(n_components=1, learning_rate='auto',init='random').fit_transform(x)
df_embeddings_2017['block'] = pd.qcut(df_embeddings_2017['TSNE'], q=5, labels = [1,2,3,4,5])

df_control = df_embeddings_2017
df_treat = df_embeddings_2018



x = np.array(df_control.embedding.tolist())
clustering = AgglomerativeClustering(n_clusters=None, distance_threshold=0.1, linkage="average", metric = 'cosine').fit(x)

df_control['agg_cluster'] = clustering.labels_.tolist()


neigh = NearestNeighbors( n_neighbors=tuning_param_knn, metric = 'cosine', radius = 0.3)
non_anchor_embedding_2018 = np.array(df_treat.embedding.to_list())
neigh.fit(non_anchor_embedding_2018)

#setting up closest centroid for anchor group 2017
anchor_embedding_2017 = np.array(df_control.embedding.tolist())
anchor_agg_clusters_2017 = np.array(df_control.agg_cluster.tolist())
clf = NearestCentroid()
clf.fit(anchor_embedding_2017, anchor_agg_clusters_2017)


#dictionary of all the agg clusters and the 20 KNN from 2018
dict_agg_cluster_matches ={}
for cluster_id in np.unique(clustering.labels_):

    distances, indices = neigh.kneighbors([clf.centroids_[cluster_id]])
    df_anchor_embedding = pd.concat([pd.DataFrame(data = distances.T,columns =['cos_dist']),pd.DataFrame(indices.T,columns=['indices'])],axis=1)

    #get all the specified cosine distance 2018 papers
    #tuple of (dataframe of 2018 matched papers, cosine distances)
    dict_agg_cluster_matches[cluster_id] = (
        df_treat.iloc[df_anchor_embedding[df_anchor_embedding['cos_dist']<= tuning_param_cos_dist].indices.to_list(), :],
        df_anchor_embedding[df_anchor_embedding['cos_dist']<= tuning_param_cos_dist].cos_dist.to_list()
    )



df_control[['titles_2018','keywords_2018','id_2018','cos_dist_2018']]= df_control.apply(lambda x: lambda_get_2018_matches(x, dict_agg_cluster_matches),axis=1, result_type ='expand')


df_control['num_knn_matches'] = df_control.apply(lambda x: get_num_knn_matches(x),axis =1)


#Matching potential outcome estimator
#Keith et al. 2020
#https://aclanthology.org/2020.acl-main.474.pdf
#equation 7 and 8
df_control['match_ave_rating'] = df_control.apply(lambda row: lambda_get_match_potential_outcomes(row), axis =1)
df_control['diff_2018_2017'] = df_control['match_ave_rating'] - df_control['AVG_rating']

df_control = df_control.loc[df_control['match_ave_rating'].notnull(),]

# %%
df_control
# Out:
#       paper_id                                          embedding         id  \
# 0    B1-Hhnslg  [-0.5121992826461792, 0.752593457698822, 0.081...  B1-Hhnslg
# 1    B1-q5Pqxl  [-0.4752337336540222, 1.326865315437317, 0.206...  B1-q5Pqxl
# 2    B16Jem9xe  [-0.4356429874897003, 0.6291022300720215, -0.6...  B16Jem9xe
# 3    B16dGcqlx  [-0.5004339814186096, -0.3711392283439636, -0....  B16dGcqlx
# 4    B184E5qee  [-0.8872877359390259, 1.4406616687774658, 0.64...  B184E5qee
# ..         ...                                                ...        ...
# 485  ryjp1c9xg  [-0.1113804280757904, 0.908949077129364, -0.22...  ryjp1c9xg
# 486  ryrGawqex  [0.13401907682418823, 0.40059706568717957, -0....  ryrGawqex
# 487  ryuxYmvel  [0.9602002501487732, 0.6227221488952637, -0.64...  ryuxYmvel
# 488  rywUcQogx  [-0.18235468864440918, 1.6256117820739746, 0.3...  rywUcQogx
# 489  ryxB0Rtxx  [-0.37102749943733215, 0.7006202340126038, 0.1...  ryxB0Rtxx
#
#                                                  title  conf_year  \
# 0          Prototypical Networks for Few-shot Learning       2017
# 1    Machine Comprehension Using Match-LSTM and Ans...       2017
# 2               Learning in Implicit Generative Models       2017
# 3                      Third Person Imitation Learning       2017
# 4    Improving Neural Language Models with a Contin...       2017
# ..                                                 ...        ...
# 485       Extensions and Limitations of the Neural GPU       2017
# 486      Deep Learning with Dynamic Computation Graphs       2017
# 487  HolStep: A Machine Learning Dataset for Higher...       2017
# 488      Differentiable Canonical Correlation Analysis       2017
# 489                  Identity Matters in Deep Learning       2017
#
#                                              keywords  AVG_rating       TSNE  \
# 0              ["Deep learning", "Transfer Learning"]    5.000000   5.125874
# 1    ["Natural language processing", "Deep learning"]    6.333333 -10.227882
# 2                           ["Unsupervised Learning"]    7.000000 -15.352392
# 3                                                  []    5.666667   1.522469
# 4                     ["Natural language processing"]    7.000000  -6.480352
# ..                                                ...         ...        ...
# 485                                                []    4.666667   3.941308
# 486                                 ["Deep learning"]    7.666667  -4.409214
# 487                                                []    7.000000  -1.638250
# 488                          ["Multi-modal learning"]    3.333333 -12.343430
# 489                                                []    6.333333   8.238441
#
#     block  agg_cluster                                        titles_2018  \
# 0       4           40  [Gaussian Prototypical Networks for Few-Shot L...
# 1       1          416  [QANet: Combining Local Convolution with Globa...
# 2       1           16  [Understanding GANs: the LQG Setting, Distribu...
# 3       3          406  [Faster Reinforcement Learning with Expert Sta...
# 4       2          378  [Memory Architectures in Recurrent Neural Netw...
# ..    ...          ...                                                ...
# 485     4           43  [Mixed Precision Training, Discovering the mec...
# 486     2           38  [Covariant Compositional Networks For Learning...
# 487     3           26  [Piecewise Linear Neural Networks verification...
# 488     1          105  [Learning Non-Metric Visual Similarity for Ima...
# 489     4            9  [Neumann Optimizer: A Practical Optimization A...
#
#                                          keywords_2018  \
# 0    [["one-shot learning", "few-shot learning", "O...
# 1    [["squad", "stanford question answering datase...
# 2    [["Generative Adversarial Networks", "Wasserst...
# 3    [["Reinforcement Learning", "Imitation Learnin...
# 4    [[], [], ["language model", "LSTM", "regulariz...
# ..                                                 ...
# 485  [["Half precision", "float16", "Convolutional ...
# 486  [["graph neural networks", "message passing", ...
# 487  [["Verification", "SMT solver", "Mixed Integer...
# 488  [["image retrieval", "visual similarity", "non...
# 489  [["Deep Learning", "Optimization"], [], ["resn...
#
#                                                id_2018  \
# 0    [HydnA1WCb, BJj6qGbRW, r1DPFCyA-, HJcSzz-CZ, B...
# 1    [B14TlG-RW, HyRnez-RW, By3v9k-RZ, HJRV1ZZAW, B...
# 2    [r1CE9GWR-, SyKoKWbC-, H1Yp-j1Cb, Hy7fDog0b, S...
# 3    [BJ7d0fW0b, S1GDXzb0b, rkHywl-A-, rJ3fy0k0Z, S...
# 4    [SkFqf0lAZ, rkfOvGbCW, SyyGPP0TZ, rkdU7tCaZ, S...
# ..                                                 ...
# 485  [r1gs9JgRZ, H1srNebAZ, Hksj2WWAW, S18Su--CW, r...
# 486  [S1TgE7WR-, SJ71VXZAZ, Hkc-TeZ0W, HkxF5RgC-, r...
# 487  [BkPrDFgR-, SkJKHMW0Z, HypkN9yRW, S1Euwz-Rb, S...
# 488  [Skvd-myR-, rkWN3g-AZ, BkN_r2lR-, HymuJz-A-, B...
# 489  [rkLyJl-0-, S1Dh8Tg0-, rkmoiMbCb, r1iuQjxCZ, r...
#
#                                          cos_dist_2018  num_knn_matches  \
# 0    [0.07642854897025586, 0.07717568040504563, 0.0...               10
# 1    [0.10350707777723411, 0.11043829982479558, 0.1...               10
# 2    [0.06548268511605393, 0.06561798204845615, 0.0...               10
# 3    [0.08591535787539428, 0.09136263243884335, 0.1...               10
# 4    [0.11959745226556517, 0.1615211778362966, 0.16...               10
# ..                                                 ...              ...
# 485  [0.123573557795432, 0.1358848712076851, 0.1398...               10
# 486  [0.14764517423135115, 0.14940227241353732, 0.1...               10
# 487  [0.15066941662438071, 0.20234474565331761, 0.2...               10
# 488  [0.16939532391224987, 0.17162936293372322, 0.1...               10
# 489  [0.06206684130863971, 0.06285094565269489, 0.0...               10
#
#      match_ave_rating  diff_2018_2017
# 0            4.766667       -0.233333
# 1            5.600000       -0.733333
# 2            5.266667       -1.733333
# 3            5.800000        0.133333
# 4            6.200000       -0.800000
# ..                ...             ...
# 485          5.700000        1.033333
# 486          5.200000       -2.466667
# 487          5.666667       -1.333333
# 488          5.266667        1.933333
# 489          5.433333       -0.900000
#
# [490 rows x 17 columns]

# %%
def create_bootstrapped_df(df, blocks):
    """
    Create "Block" Bootstrapped DataFrame given a vector of sampled_personids

    Keyword Args:
        df: DataFrame containing cost data at the personid, month level
        sampled_personids: A vector of personids that is already sampled with replacement.
    """
    bootstrapped = []
    for block in blocks:
        block_df = df.loc[df.block == block]
        bootstrapped.append(block_df)
    bootstrapped_sample = pd.concat(bootstrapped)
    bootstrapped_sample.reset_index(drop=True, inplace=True)
    return bootstrapped_sample

# %%
B = 100
S = 100

S_list = []

for s in tqdm(range(S)):
    block_boot_att = []

    for b in range(B):
        blocks = df_control.block.unique()
        block_bootstrap_sample = np.random.choice(blocks, size=blocks.size, replace=True)
        df = create_bootstrapped_df(df_control,block_bootstrap_sample)
        ATT = (df['match_ave_rating'] - df['AVG_rating']).sum()/df_control.shape[0]
        block_boot_att.append(ATT)


    mean_B_ATT = np.mean(block_boot_att)

    holder_list = []
    for b in B_ATT:
        holder_list.append((b-mean_B_ATT)**2)

    SE = np.sqrt((1/(len(B_ATT)-1)) * sum(holder_list))
    
    S_list.append(SE)
# Out:
# 100%|█████████████████████████████████████████| 100/100 [00:13<00:00,  7.27it/s]

# %%
plt.hist(S_list)
# Out:
# (array([33., 20., 19., 11., 10.,  1.,  1.,  3.,  1.,  1.]),
#  array([0.05738526, 0.05781254, 0.05823981, 0.05866709, 0.05909437,
#         0.05952164, 0.05994892, 0.06037619, 0.06080347, 0.06123075,
#         0.06165802]),
#  <BarContainer object of 10 artists>)
